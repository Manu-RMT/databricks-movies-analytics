-- %%
-- select * from tmdb_movies where vote_average like '% a nie dzięki widzeniu"""%' or id=133086;

select * from dim_film_genre;
select * from dim_film_production_country;
select * from dim_film_production_companie;
select * from dim_film_spoken_language;

select * from silver_tmdb_movies_production_companie;
select * from silver_tmdb_movies_spoken_language;
select * from silver_tmdb_movies_production_country;


select count(*) from dim_film_genre;
select count(*) from dim_film_production_country;
select count(*) from dim_film_production_companie;
select count(*) from dim_film_spoken_language;

select count(*) from silver_tmdb_movies_production_companie;
select count(*)  from silver_tmdb_movies_spoken_language;
select count(*)  from silver_tmdb_movies_production_country;
